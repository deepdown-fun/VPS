# %%
# !jupyter contrib nbextension install --user
# Out:
# [I 12:51:43 InstallContribNbextensionsApp] jupyter contrib nbextension install --user
# [I 12:51:43 InstallContribNbextensionsApp] Installing jupyter_contrib_nbextensions nbextension files to jupyter data directory
# [I 12:51:43 InstallContribNbextensionsApp] Installing /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/highlighter -> highlighter
# [I 12:51:43 InstallContribNbextensionsApp] Making directory: /root/.local/share/jupyter/nbextensions/highlighter/
# [I 12:51:43 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/highlighter/tst_highlights.ipynb -> /root/.local/share/jupyter/nbextensions/highlighter/tst_highlights.ipynb
# [I 12:51:43 InstallContribNbextensionsApp] Copying: /opt/conda/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/highlighter/tst_highlights.pdf -> /root/.local/share/jupyter/nbextensions/highlighter/tst_highlights.pdf
# ...
